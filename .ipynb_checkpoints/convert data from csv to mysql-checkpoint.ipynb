# %%
import pandas as pd
import sqlalchemy
import os
import random

URI = 'mysql+mysqlconnector://' + os.environ.get('MYSQL_USER') + ':' + os.environ.get('MYSQL_PASSWORD') + '@localhost/' + os.environ.get('MYSQL_DB')
connection = sqlalchemy.create_engine(URI)

df = pd.read_csv('~/Desktop/goodbooks-10k/books.csv')
df = df[['book_id', 'original_title', 'isbn','authors', 'original_publication_year','image_url', 'average_rating', 'books_count']]
df.sort_values(inplace=True, by = ['book_id'])

# %%
from Book_Flask import db
resudb.engine.execute("CREATE DATABASE IF NOT EXISTS borestook CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;")
db.create_all
# Out:
# <bound method SQLAlchemy.create_all of <SQLAlchemy engine=mysql+mysqlconnector://flask:***@localhost/borestook?charset=utf8>>

# %%
data = [{'GenreID': 1, 'Name': 'Science fiction'},
       {'GenreID': 2, 'Name': 'Satire'},
       {'GenreID': 3, 'Name': 'Drama'},
       {'GenreID': 4, 'Name': 'Romance'},
       {'GenreID': 5, 'Name': 'Mystery'},
       {'GenreID': 6, 'Name': 'Horror'},
       {'GenreID': 7, 'Name': 'Self help'},
       {'GenreID': 8, 'Name': 'Health'},
       {'GenreID': 9, 'Name': 'Guide'},
       {'GenreID': 10, 'Name': 'Travel'},
       {'GenreID': 11, 'Name': 'Religion, Spirituality & New Age'},
       {'GenreID': 12, 'Name': 'Science'},
       {'GenreID': 13, 'Name': 'History'},
       {'GenreID': 14, 'Name': 'Math'},
       {'GenreID': 15, 'Name': 'Anthology'},
       {'GenreID': 16, 'Name': 'Poetry'},
       {'GenreID': 17, 'Name': 'Encyclopedias'},
       {'GenreID': 18, 'Name': 'Dictionaries'},
       {'GenreID': 19, 'Name': 'Comics'},
       {'GenreID': 20, 'Name': 'Cookbooks'},
       {'GenreID': 21, 'Name': 'Diaries'},
       {'GenreID': 22, 'Name': 'Journals'},
       {'GenreID': 23, 'Name': 'Prayer books'},
       {'GenreID': 24, 'Name': 'Series'},
       {'GenreID': 25, 'Name': 'Trilogy'},
       {'GenreID': 26, 'Name': 'Biographies'},
       {'GenreID': 27, 'Name': 'Autobiographies'},
       {'GenreID': 28, 'Name': 'Fantasy'},
       {'GenreID': 29, 'Name': 'Others'}]

# %%
data_genres = pd.DataFrame(data)

# %%
authors_name = []

for i in range(len(df['book_id']) - 1):
    for x in (df.iloc[i]['authors']).split(','):
        temp = x.strip()
        if temp not in authors_name:
            authors_name.append(temp)

authors_id = []
for i in range(len(authors_name)):
    authors_id.append(i+1)

# %%
data_authors = pd.DataFrame({'AuthorID': authors_id, 'Name': authors_name})

# %%
a = data_authors[data_authors['Name'] == 'J.K. Rowling'].values[0].tolist()
a[1]
# Out:
# 'J.K. Rowling'

# %%
def get_id_of_author(s):
    temp = data_authors[data_authors['Name'] == s].values[0].tolist()
    return temp[0]

# %%
get_id_of_author('Frank Herbert')
# Out:
# 20

# %%
def replace_author(s):
    authors_id = ''
    for word in s.split(','):
        stripped_word = word.strip()
        if stripped_word in authors_name:
            if authors_id != '':
                authors_id += (', ' + str(get_id_of_author(stripped_word)))
            else:
                authors_id += str(get_id_of_author(stripped_word))
    return authors_id

# %%
replace_author('Heidi Murkoff, Sharon Mazel, Heidi Murkoff, Arlene Eisenberg, Sandee Hathaway, Mark D. Widome')
# Out:
# '15, 16, 15, 17, 18, 19'

# %%
temp = []
for x in range(len(df['book_id'])):
    temp.append(df.iloc[x]['authors'])

# %%
own = []
for i in temp:
    own.append(replace_author(i))

# %%
df['authors'] = own

# %%
random_genre = []
random_price = []
for i in range(len(df['book_id'])):
    random_genre.append(random.randint(1, len(data)))

for i in range(len(df['book_id'])):
    random_price.append(random.randint(5, 500))

# %%
df['GenreID'] = random_genre
df['Price'] = random_price

# %%
df.rename(columns = {'authors' : 'AuthorsID',
                     'book_id' : 'BookID',
                     'original_title' : 'Title',
                     'isbn' : 'ISBN',
                     'original_publication_year' : 'PublicationYear',
                     'image_url' : 'ImgUrl',
                     'average_rating': 'AvgRating',
                     'books_count' : 'Quantity'}, inplace = True)

# %%
df = df[['BookID', 'Title', 'ISBN', 'AuthorsID', 'PublicationYear', 'ImgUrl', 'Price', 'AvgRating', 'Quantity', 'GenreID']]

# %%
#delete book with no image
df = df[df.ImgUrl != 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png']
#delete book with no title
df = df[df.Title != ' '].shape
# Out:
#         BookID                                              Title        ISBN  \
# 26           1             Harry Potter and the Half-Blood Prince   439785960
# 20           2          Harry Potter and the Order of the Phoenix   439358078
# 1            3           Harry Potter and the Philosopher's Stone   439554934
# 17           5           Harry Potter and the Prisoner of Azkaban  043965548X
# 23           6                Harry Potter and the Goblet of Fire   439139600
# 3274         8                                                NaN   439682584
# 3752        10       Harry Potter Collection (Harry Potter, #1-6)   439827604
# 53          11               The Hitchhiker's Guide to the Galaxy   345391802
# 336         13  The Ultimate Hitchhiker's Guide: Five Complete...   345453743
# 373         21               A Short History of Nearly Everything  076790818X
# 1459        24                                         Down Under   767903862
# 1975        25                           Notes from a Big Country  076790382X
# 2320        26  The Lost Continent: Travels in Small-Town America    60920084
# 2278        27          Neither Here Nor There: Travels in Europe   380713802
# 1448        28                          Notes from a Small Island   380727501
# 4078        29  The Mother Tongue: English and How It Got That...   380715430
# 963         30               The Hobbit and The Lord of the Rings   345538374
# 188         33                              The Lord of the Rings   618640150
# 18          34                         The Fellowship of the Ring   618346252
# 4228        36         The Lord of the Rings: Weapons and Warfare   618391002
# 387         50                                            Hatchet   689840926
# 3503        67                                    The Known World    61159174
# 638         93                                              Heidi   753454947
# 7682        98                      What to Expect the First Year   761129588
# 2816       105                                 Chapterhouse: Dune   441102670
# 1104       106                                      Dune Messiah    441172695
# 1261       112                                   Children of Dune   441104029
# 2490       117                                   Heretics of Dune   441328008
# 3229       119  The Lord of the Rings: The Art of The Fellowsh...   618212906
# 1596       122                                   The Power of One  034541005X
# ...        ...                                                ...         ...
# 3986  29632984                                                NaN         NaN
# 2331  29639736                                 Everything We Keep         NaN
# 3884  29780253                                                NaN   385689225
# 4851  29868610                              Scrappy Little Nobody  1501117203
# 9391  29906980                               Lincoln in the Bardo   812995341
# 8582  29925715                                         The Sister         NaN
# 7702  29975458                                       Good as Gone   544920953
# 2272  29981261                               The Butterfly Garden         NaN
# 8204  29991719                                    Royally Screwed         NaN
# 5218  30002998                                         Two By Two         NaN
# 6442  30008702                                           Nutshell   385542070
# 4640  30065028  Fantastic Beasts and Where to Find Them: The O...         NaN
# 7447  30226723                                        King's Cage    62310712
# 9412  30253700                                                NaN         NaN
# 4575  30253864  Talking as Fast as I Can: From Gilmore Girls t...   425285170
# 7093  30314465                                      No Man's Land         NaN
# 9815  30364931                                                NaN         NaN
# 1538  30555488                           The Underground Railroad   385542364
# 5883  30831912                                    Norse Mythology         NaN
# 9547  30839185                                            Vicious         NaN
# 5110  31140847                                                NaN         NaN
# 5295  31176886                                        The Chemist         NaN
# 8712  31194270                                      Evelyn, After         NaN
# 7442  31538614  Short Stories from Hogwarts of Power, Politics...  1781106290
# 6427  31538635  Short Stories from Hogwarts of Heroism, Hardsh...  1781106282
# 7522  31538647       Hogwarts: An Incomplete and Unreliable Guide         NaN
# 4593  31845516                                       Love Warrior  1250128544
# 9568  32075671                                    The Hate U Give    62498533
# 9579  32848471                                                NaN  1682309819
# 8891  33288638                                        Wait for It         NaN
#
#                    AuthorsID  PublicationYear  \
# 26                      1, 2           2005.0
# 20                      1, 2           2003.0
# 1                       1, 2           1997.0
# 17                   1, 2, 3           1999.0
# 23                      1, 2           2000.0
# 3274                    1, 2           2003.0
# 3752                       1           2005.0
# 53                         4           1979.0
# 336                        4           1996.0
# 373                        5           2003.0
# 1459                       5           2000.0
# 1975                       5           1998.0
# 2320                       5           1989.0
# 2278                       5           1991.0
# 1448                       5           1995.0
# 4078                       5           1990.0
# 963                        6           1973.0
# 188                        6           1955.0
# 18                         6           1954.0
# 4228                 7, 8, 9              NaN
# 387                       10           1986.0
# 3503                      11           2003.0
# 638               12, 13, 14           1880.0
# 7682  15, 16, 15, 17, 18, 19           1989.0
# 2816                      20           1985.0
# 1104                      20           1969.0
# 1261                      20           1976.0
# 2490                      20           1984.0
# 3229                      21           2002.0
# 1596                      22           1989.0
# ...                      ...              ...
# 3986                    5831           2016.0
# 2331                    5832           2016.0
# 3884                    5833           2016.0
# 4851                    5834           2016.0
# 9391                     850           2017.0
# 8582                    5835           2016.0
# 7702                    5836           2016.0
# 2272                    5837           2016.0
# 8204                    5400           2016.0
# 5218                     257           2016.0
# 6442                     378           2016.0
# 4640                       1           2016.0
# 7447                    5386           2017.0
# 9412                    5256           2016.0
# 4575                    5232           2016.0
# 7093                     883           2016.0
# 9815                    5449           2016.0
# 1538                    4770           2016.0
# 5883                     224           2017.0
# 9547                    5838           2016.0
# 5110                    5422           2016.0
# 5295                    1636           2016.0
# 8712                    5839           2016.0
# 7442                 1, 5840           2016.0
# 6427                 1, 5840           2016.0
# 7522                       1           2016.0
# 4593                    5173           2016.0
# 9568                    5841           2017.0
# 9579                    5422           2017.0
# 8891                    5560           2016.0
#
#                                                  ImgUrl  Price  AvgRating  \
# 26    https://images.gr-assets.com/books/1361039191m...    122       4.54
# 20    https://images.gr-assets.com/books/1387141547m...    319       4.46
# 1     https://images.gr-assets.com/books/1474154022m...    407       4.44
# 17    https://images.gr-assets.com/books/1499277281m...    376       4.53
# 23    https://images.gr-assets.com/books/1361482611m...    306       4.53
# 3274  https://s.gr-assets.com/assets/nophoto/book/11...    496       4.77
# 3752  https://images.gr-assets.com/books/1328867351m...    244       4.73
# 53    https://images.gr-assets.com/books/1327656754m...     23       4.20
# 336   https://images.gr-assets.com/books/1404613595m...     87       4.37
# 373   https://s.gr-assets.com/assets/nophoto/book/11...    309       4.19
# 1459  https://s.gr-assets.com/assets/nophoto/book/11...    168       4.05
# 1975  https://s.gr-assets.com/assets/nophoto/book/11...    207       3.89
# 2320  https://images.gr-assets.com/books/1404042682m...    488       3.83
# 2278  https://s.gr-assets.com/assets/nophoto/book/11...    198       3.88
# 1448  https://images.gr-assets.com/books/1479653223m...    414       3.91
# 4078  https://images.gr-assets.com/books/1388209925m...    208       3.95
# 963   https://images.gr-assets.com/books/1346072396m...    202       4.59
# 188   https://images.gr-assets.com/books/1411114164m...    205       4.47
# 18    https://images.gr-assets.com/books/1298411339m...     19       4.34
# 4228  https://s.gr-assets.com/assets/nophoto/book/11...    496       4.53
# 387   https://s.gr-assets.com/assets/nophoto/book/11...    281       3.68
# 3503  https://s.gr-assets.com/assets/nophoto/book/11...    154       3.82
# 638   https://s.gr-assets.com/assets/nophoto/book/11...     16       3.97
# 7682  https://s.gr-assets.com/assets/nophoto/book/11...    379       3.86
# 2816  https://images.gr-assets.com/books/1260954505m...    344       3.89
# 1104  https://images.gr-assets.com/books/1392528394m...    465       3.86
# 1261  https://s.gr-assets.com/assets/nophoto/book/11...    457       3.90
# 2490  https://s.gr-assets.com/assets/nophoto/book/11...    223       3.83
# 3229  https://s.gr-assets.com/assets/nophoto/book/11...     52       4.59
# 1596  https://s.gr-assets.com/assets/nophoto/book/11...    443       4.34
# ...                                                 ...    ...        ...
# 3986  https://s.gr-assets.com/assets/nophoto/book/11...    115       3.83
# 2331  https://s.gr-assets.com/assets/nophoto/book/11...    393       3.84
# 3884  https://images.gr-assets.com/books/1473867911m...    161       4.49
# 4851  https://images.gr-assets.com/books/1469410391m...    453       3.91
# 9391  https://images.gr-assets.com/books/1492130850m...    343       3.93
# 8582  https://s.gr-assets.com/assets/nophoto/book/11...    463       3.77
# 7702  https://images.gr-assets.com/books/1464329788m...    479       3.53
# 2272  https://images.gr-assets.com/books/1461392121m...    210       4.07
# 8204  https://images.gr-assets.com/books/1463068765m...     59       4.11
# 5218  https://images.gr-assets.com/books/1461620101m...     81       3.90
# 6442  https://images.gr-assets.com/books/1498680109m...     72       3.71
# 4640  https://images.gr-assets.com/books/1476913365m...    380       4.41
# 7447  https://images.gr-assets.com/books/1467121158m...    385       4.03
# 9412  https://images.gr-assets.com/books/1465493571m...    307       4.14
# 4575  https://images.gr-assets.com/books/1492797634m...    413       4.04
# 7093  https://images.gr-assets.com/books/1469561999m...    222       4.19
# 9815  https://images.gr-assets.com/books/1467960990m...    124       4.23
# 1538  https://images.gr-assets.com/books/1493178362m...    104       4.04
# 5883  https://images.gr-assets.com/books/1473864212m...    221       4.12
# 9547  https://images.gr-assets.com/books/1481945407m...    354       4.25
# 5110  https://s.gr-assets.com/assets/nophoto/book/11...    182       4.25
# 5295  https://images.gr-assets.com/books/1468944057m...    148       3.69
# 8712  https://s.gr-assets.com/assets/nophoto/book/11...    357       3.64
# 7442  https://images.gr-assets.com/books/1471436601m...     22       4.20
# 6427  https://images.gr-assets.com/books/1471436733m...    113       4.22
# 7522  https://images.gr-assets.com/books/1502156557m...    464       4.21
# 4593  https://images.gr-assets.com/books/1473164102m...    439       4.10
# 9568  https://images.gr-assets.com/books/1476284759m...     68       4.62
# 9579  https://images.gr-assets.com/books/1479387807m...    223       4.34
# 8891  https://s.gr-assets.com/assets/nophoto/book/11...     17       4.22
#
#       Quantity  GenreID
# 26         275       18
# 20         307       13
# 1          491       19
# 17         376       19
# 23         332       14
# 3274        11       27
# 3752         6       17
# 53         257       28
# 336         32       22
# 373        155       20
# 1459        76       26
# 1975        69       23
# 2320        47       20
# 2278        57       24
# 1448        63       17
# 4078        28       29
# 963         74       16
# 188        380        4
# 18         566       28
# 4228        12       14
# 387         93        8
# 3503        42       16
# 638        771       29
# 7682        45       20
# 2816        72       11
# 1104       140        7
# 1261       116        5
# 2490        86        9
# 3229         7        2
# 1596        82       10
# ...        ...      ...
# 3986         8       16
# 2331        15        7
# 3884        23       14
# 4851        19        9
# 9391         2       24
# 8582        13       15
# 7702        26        9
# 2272        21       25
# 8204         8       28
# 5218        43       11
# 6442        47       29
# 4640        49        3
# 7447        11       28
# 9412         7       25
# 4575        23       17
# 7093        29        7
# 9815         7       22
# 1538        48       26
# 5883        38       29
# 9547         4       23
# 5110        16       11
# 5295        66       28
# 8712         5       10
# 7442        18       10
# 6427        18        8
# 7522        18       22
# 4593        20       16
# 9568        36        4
# 9579         8       13
# 8891         4       21
#
# [10000 rows x 10 columns]

# %%
data_authors.set_index('AuthorID', inplace = True)

data_authors.to_sql(con = connection, name = 'author', if_exists = 'append')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     505     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 506         cursor.executemany(statement, parameters)
#     507
#
# ~/py_36_env/lib/python3.6/site-packages/mysql/connector/cursor.py in executemany(self, operation, seq_params)
#     653             if stmt is not None:
# --> 654                 return self.execute(stmt)
#     655
#
# ~/py_36_env/lib/python3.6/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#
# ~/py_36_env/lib/python3.6/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     489             query = query.encode('utf-8')
# --> 490         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     491
#
# ~/py_36_env/lib/python3.6/site-packages/mysql/connector/connection.py in _handle_result(self, packet)
#     394         elif packet[4] == 255:
# --> 395             raise errors.get_exception(packet)
#     396
#
# IntegrityError: 1062 (23000): Duplicate entry '1' for key 'PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-21-051b9512121c> in <module>
#       1 data_authors.set_index('AuthorID', inplace = True)
#       2
# ----> 3 data_authors.to_sql(con = connection, name = 'author', if_exists = 'append')
#
# ~/py_36_env/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# ~/py_36_env/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~/py_36_env/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# ~/py_36_env/lib/python3.6/site-packages/pandas/io/sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~/py_36_env/lib/python3.6/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1168                         statement,
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#    1172                 if self.dialect._has_events:
#
# ~/py_36_env/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     504
#     505     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 506         cursor.executemany(statement, parameters)
#     507
#     508     def do_execute(self, cursor, statement, parameters, context=None):
#
# ~/py_36_env/lib/python3.6/site-packages/mysql/connector/cursor.py in executemany(self, operation, seq_params)
#     652             stmt = self._batch_insert(operation, seq_params)
#     653             if stmt is not None:
# --> 654                 return self.execute(stmt)
#     655
#     656         rowcnt = 0
#
# ~/py_36_env/lib/python3.6/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     549         else:
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#     553                 if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~/py_36_env/lib/python3.6/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488         if not isinstance(query, bytes):
#     489             query = query.encode('utf-8')
# --> 490         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     491
#     492         if self._have_next_result:
#
# ~/py_36_env/lib/python3.6/site-packages/mysql/connector/connection.py in _handle_result(self, packet)
#     393             return self._handle_eof(packet)
#     394         elif packet[4] == 255:
# --> 395             raise errors.get_exception(packet)
#     396
#     397         # We have a text result set
#
# IntegrityError: (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry '1' for key 'PRIMARY' [SQL: 'INSERT INTO author (`AuthorID`, `Name`) VALUES (%(AuthorID)s, %(Name)s)'] [parameters: ({'AuthorID': 1, 'Name': 'J.K. Rowling'}, {'AuthorID': 2, 'Name': 'Mary GrandPré'}, {'AuthorID': 3, 'Name': 'Rufus Beck'}, {'AuthorID': 4, 'Name': 'Douglas Adams'}, {'AuthorID': 5, 'Name': 'Bill Bryson'}, {'AuthorID': 6, 'Name': 'J.R.R. Tolkien'}, {'AuthorID': 7, 'Name': 'Chris   Smith'}, {'AuthorID': 8, 'Name': 'Christopher Lee'}  ... displaying 10 of 5841 total bound parameter sets ...  {'AuthorID': 5840, 'Name': 'MinaLima'}, {'AuthorID': 5841, 'Name': 'Angie Thomas'})] (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
data_genres.set_index('GenreID', inplace = True)

data_genres.to_sql(con = connection, name = 'genre', if_exists='append')

# %%
BookID = df['BookID'].values.tolist()
Title = df['Title'].values.tolist()
ISBN = df['ISBN'].values.tolist()
AuthorsID = df['AuthorsID'].values.tolist()
PublicationYear = df['PublicationYear'].values.tolist()
ImgUrl = df['ImgUrl'].values.tolist()
Price = df['Price'].values.tolist()
AvgRating = df['AvgRating'].values.tolist()
Quantity = df['Quantity'].values.tolist()
GenreID = df['GenreID'].values.tolist()

# %%
book = pd.DataFrame({'BookID':BookID})
book['Title'] = Title
book['ISBN'] = ISBN
book['AuthorsID'] = AuthorsID
book['PublicationYear'] = PublicationYear
book['ImgUrl'] = ImgUrl
book['Price'] = Price
book['AvgRating'] = AvgRating
book['Quantity'] = Quantity
book['GenreID'] = GenreID

# %%
book['Title'].fillna('Unkown', inplace = True)

# %%
book.set_index('BookID', inplace = True)

# %%
book.to_sql(con = connection, name = 'book', if_exists='append')

# %%
df[df.Title != ' '].shape
# Out:
# (9995, 10)
